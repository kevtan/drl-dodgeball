# %%
from mlagents.envs.environment import UnityEnvironment, BrainParameters
import numpy as np
from qlearning_agent import *
from function_approximators import *
import tqdm

# %% [markdown]
# ## Setup Environment

# %%
env = UnityEnvironment(file_name = "environment-binaries/PushBlock-no-stack-small.app", timeout_wait=5)
# env = UnityEnvironment(file_name=None)
# Out:
# INFO:mlagents.envs:
# 'Academy (1)' started successfully!
# Unity Academy name: Academy (1)
#         Number of Training Brains : 0
#         Reset Parameters :
# 		block_scale -> 2.0
# 		static_friction -> 0.0
# 		dynamic_friction -> 0.0
# 		block_drag -> 0.5

# %% [markdown]
# ## Setup Agent

# %%
env.step()
env.reset()
for name, brain in env.brains.items():
    print(f"Brain name: {name}")
    parameters = env.brains[name]
    print("State space size:\t", parameters.vector_observation_space_size)
    print("Action space size:\t", parameters.vector_action_space_size)
    print("Action space type:\t", parameters.vector_action_space_type)

state_space_size = parameters.vector_observation_space_size
action_space_size = parameters.vector_observation_space_size
action_space_type = parameters.vector_action_space_type
# Out:
# Brain name: PushBlock
# State space size:	 70
# Action space size:	 [7]
# Action space type:	 discrete

# %%
actions = (0,1,2,3,4,5,6)
approximator = LinearFunctionApproximator(state_space_size, action_space_size, actions)
agent = QLearningAgent(actions, approximator)

# %% [markdown]
# ## Training

# %%
max_episodes = 100
max_timestep = 100

# %%
info = env.step()

# %%
#This is merely a test to see how the agent reacts when prompted with actions
#for i in range(100):
#    info = env.step(0)["PushBlock"]

# %%
info["VisualFoodCollector"].vector_observations
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-e810c5723a7e> in <module>
# ----> 1 info["VisualFoodCollector"].vector_observations
#
# KeyError: 'VisualFoodCollector'

# %%
rewards_all_episodes = []
for _ in tqdm.tqdm(range(max_episodes)):
    rewards_current_episode = 0
    info = env.step()["PushBlock"]
    for _ in range(max_timestep):
        reward = info.rewards[0]
        rewards_current_episode += reward
        state = (info.vector_observations)[0]
        agent.give_feedback(reward, state)
        action = agent.get_action(state)
        info = env.step(action)["PushBlock"]
    rewards_all_episodes.append(rewards_current_episode)
    env.reset(train_mode=True)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-0133d670123c> in <module>
#       8         state = (info.vector_observations)[0]
#       9         agent.give_feedback(reward, state)
# ---> 10         action = agent.get_action(state)
#      11         info = env.step(action)["PushBlock"]
#      12     rewards_all_episodes.append(rewards_current_episode)
#
# /afs/ir.stanford.edu/users/a/n/andykhuu/Desktop/dodgeball/qlearning_agent.py in get_action(self, state)
#      36         best_value = -float("inf")
#      37         for action in self.actions:
# ---> 38             value = self.ftn_approximator.predict_q(state, action)
#      39             if value > best_value:
#      40                 best_action = action
#
# /afs/ir.stanford.edu/users/a/n/andykhuu/Desktop/dodgeball/function_approximators.py in predict_q(self, state, action)
#      15             action = np.array([action])
#      16         state_action = np.concatenate((state, action))
# ---> 17         return np.dot(state_action, self.weights)
#      18
#      19     def update_weights(self, old_state, action, reward, new_state):
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (71,) and (140,) not aligned: 71 (dim 0) != 140 (dim 0)

# %% [markdown]
# ## Teardown Environment

# %%
env.close()
# Out:
# INFO:mlagents.envs:Environment shut down with return code 0.
